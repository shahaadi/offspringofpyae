# %%
import pandas as pd
import numpy as np
import os

ncs_raw = pd.read_csv('ncs_raw.csv', sep=';')
print(ncs_raw.shape)
ncs_raw.head()
# Out:
# (1111, 106)
#                  channel_id     video_id  \
# 0  UC_aEa8K-EOJ3D6gOs7HcyNg  vTLrfrkBDp8
# 1  UC_aEa8K-EOJ3D6gOs7HcyNg  qijbn1Fcq_I
# 2  UC_aEa8K-EOJ3D6gOs7HcyNg  _zvzWG9tKzI
# 3  UC_aEa8K-EOJ3D6gOs7HcyNg  _OLrjAWzUR0
# 4  UC_aEa8K-EOJ3D6gOs7HcyNg  rUt7qOHwh1s
#
#                                                title  duration  view_count  \
# 0               T & Sugah - Indecisive [NCS Release]     214.0      143632
# 1      Raude - paradise (feat. Ntsika) [NCS Release]     152.0      159827
# 2                    C1W - Driver Seat [NCS Release]     149.0      170539
# 3              Clarx & Zaug - No Money [NCS Release]     119.0      228235
# 4  Britt Lari & Ray Le Fanue - What I Want [NCS R...     130.0      210392
#
#    t_step  datapoint_0  datapoint_1  datapoint_2  datapoint_3  ...  \
# 0  2140.0     0.034883          0.0     0.028439     0.046544  ...
# 1  1520.0     0.044386          0.0     0.043074     0.070807  ...
# 2  1490.0     0.074010          0.0     0.027107     0.052641  ...
# 3  1190.0     0.040056          0.0     0.056302     0.090392  ...
# 4  1300.0     0.021479          0.0     0.028877     0.066285  ...
#
#    datapoint_90  datapoint_91  datapoint_92  datapoint_93  datapoint_94  \
# 0      0.967818      0.964090      0.973908      0.978677      0.989083
# 1      1.000000      0.992251      0.977241      0.977201      0.973159
# 2      0.980443      0.980796      0.983149      0.985826      0.985274
# 3      0.984439      0.991178      0.995789      0.998120      0.999640
# 4      0.996590      0.988758      0.971256      0.962779      0.955974
#
#    datapoint_95  datapoint_96  datapoint_97  datapoint_98  datapoint_99
# 0      1.000000      0.999283      0.998590      0.979921      0.993675
# 1      0.973217      0.973392      0.972385      0.970316      0.975626
# 2      0.975527      0.986906      0.995770      1.000000      0.998612
# 3      0.996690      1.000000      0.990731      0.988720      0.954516
# 4      0.944535      0.933863      0.926431      0.939607      0.922554
#
# [5 rows x 106 columns]

# %%
# ncs_raw.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'], inplace=True)
print(ncs_raw.shape)
ncs_raw.head()
# Out:
# (1111, 106)
#                  channel_id     video_id  \
# 0  UC_aEa8K-EOJ3D6gOs7HcyNg  vTLrfrkBDp8
# 1  UC_aEa8K-EOJ3D6gOs7HcyNg  qijbn1Fcq_I
# 2  UC_aEa8K-EOJ3D6gOs7HcyNg  _zvzWG9tKzI
# 3  UC_aEa8K-EOJ3D6gOs7HcyNg  _OLrjAWzUR0
# 4  UC_aEa8K-EOJ3D6gOs7HcyNg  rUt7qOHwh1s
#
#                                                title  duration  view_count  \
# 0               T & Sugah - Indecisive [NCS Release]     214.0      143632
# 1      Raude - paradise (feat. Ntsika) [NCS Release]     152.0      159827
# 2                    C1W - Driver Seat [NCS Release]     149.0      170539
# 3              Clarx & Zaug - No Money [NCS Release]     119.0      228235
# 4  Britt Lari & Ray Le Fanue - What I Want [NCS R...     130.0      210392
#
#    t_step  datapoint_0  datapoint_1  datapoint_2  datapoint_3  ...  \
# 0  2140.0     0.034883          0.0     0.028439     0.046544  ...
# 1  1520.0     0.044386          0.0     0.043074     0.070807  ...
# 2  1490.0     0.074010          0.0     0.027107     0.052641  ...
# 3  1190.0     0.040056          0.0     0.056302     0.090392  ...
# 4  1300.0     0.021479          0.0     0.028877     0.066285  ...
#
#    datapoint_90  datapoint_91  datapoint_92  datapoint_93  datapoint_94  \
# 0      0.967818      0.964090      0.973908      0.978677      0.989083
# 1      1.000000      0.992251      0.977241      0.977201      0.973159
# 2      0.980443      0.980796      0.983149      0.985826      0.985274
# 3      0.984439      0.991178      0.995789      0.998120      0.999640
# 4      0.996590      0.988758      0.971256      0.962779      0.955974
#
#    datapoint_95  datapoint_96  datapoint_97  datapoint_98  datapoint_99
# 0      1.000000      0.999283      0.998590      0.979921      0.993675
# 1      0.973217      0.973392      0.972385      0.970316      0.975626
# 2      0.975527      0.986906      0.995770      1.000000      0.998612
# 3      0.996690      1.000000      0.990731      0.988720      0.954516
# 4      0.944535      0.933863      0.926431      0.939607      0.922554
#
# [5 rows x 106 columns]

# %%
ncs_raw = ncs_raw[ncs_raw['datapoint_0'].notna()]
print(ncs_raw.shape)
ncs_raw.head()
# Out:
# (1111, 106)
#                  channel_id     video_id  \
# 0  UC_aEa8K-EOJ3D6gOs7HcyNg  vTLrfrkBDp8
# 1  UC_aEa8K-EOJ3D6gOs7HcyNg  qijbn1Fcq_I
# 2  UC_aEa8K-EOJ3D6gOs7HcyNg  _zvzWG9tKzI
# 3  UC_aEa8K-EOJ3D6gOs7HcyNg  _OLrjAWzUR0
# 4  UC_aEa8K-EOJ3D6gOs7HcyNg  rUt7qOHwh1s
#
#                                                title  duration  view_count  \
# 0               T & Sugah - Indecisive [NCS Release]     214.0      143632
# 1      Raude - paradise (feat. Ntsika) [NCS Release]     152.0      159827
# 2                    C1W - Driver Seat [NCS Release]     149.0      170539
# 3              Clarx & Zaug - No Money [NCS Release]     119.0      228235
# 4  Britt Lari & Ray Le Fanue - What I Want [NCS R...     130.0      210392
#
#    t_step  datapoint_0  datapoint_1  datapoint_2  datapoint_3  ...  \
# 0  2140.0     0.034883          0.0     0.028439     0.046544  ...
# 1  1520.0     0.044386          0.0     0.043074     0.070807  ...
# 2  1490.0     0.074010          0.0     0.027107     0.052641  ...
# 3  1190.0     0.040056          0.0     0.056302     0.090392  ...
# 4  1300.0     0.021479          0.0     0.028877     0.066285  ...
#
#    datapoint_90  datapoint_91  datapoint_92  datapoint_93  datapoint_94  \
# 0      0.967818      0.964090      0.973908      0.978677      0.989083
# 1      1.000000      0.992251      0.977241      0.977201      0.973159
# 2      0.980443      0.980796      0.983149      0.985826      0.985274
# 3      0.984439      0.991178      0.995789      0.998120      0.999640
# 4      0.996590      0.988758      0.971256      0.962779      0.955974
#
#    datapoint_95  datapoint_96  datapoint_97  datapoint_98  datapoint_99
# 0      1.000000      0.999283      0.998590      0.979921      0.993675
# 1      0.973217      0.973392      0.972385      0.970316      0.975626
# 2      0.975527      0.986906      0.995770      1.000000      0.998612
# 3      0.996690      1.000000      0.990731      0.988720      0.954516
# 4      0.944535      0.933863      0.926431      0.939607      0.922554
#
# [5 rows x 106 columns]

# %%
tags = ['release', '[ncs official video]', 'lyric']

drop_rows = []

for i, title, vid_id, duration, datapoint_99 in zip(ncs_raw.index, ncs_raw['title'], ncs_raw['video_id'], ncs_raw['duration'], ncs_raw['datapoint_99']):
    title = title.lower()
    if not(any(tag in title for tag in tags) and duration > 60 and datapoint_99 != 1):
        drop_rows.append(i)
        print(i, vid_id, duration, title, sep='\t')

ncs_raw.drop(index=drop_rows, inplace=True)
print(ncs_raw.shape)
ncs_raw.head()
# Out:
# (1111, 106)
#                  channel_id     video_id  \
# 0  UC_aEa8K-EOJ3D6gOs7HcyNg  vTLrfrkBDp8
# 1  UC_aEa8K-EOJ3D6gOs7HcyNg  qijbn1Fcq_I
# 2  UC_aEa8K-EOJ3D6gOs7HcyNg  _zvzWG9tKzI
# 3  UC_aEa8K-EOJ3D6gOs7HcyNg  _OLrjAWzUR0
# 4  UC_aEa8K-EOJ3D6gOs7HcyNg  rUt7qOHwh1s
#
#                                                title  duration  view_count  \
# 0               T & Sugah - Indecisive [NCS Release]     214.0      143632
# 1      Raude - paradise (feat. Ntsika) [NCS Release]     152.0      159827
# 2                    C1W - Driver Seat [NCS Release]     149.0      170539
# 3              Clarx & Zaug - No Money [NCS Release]     119.0      228235
# 4  Britt Lari & Ray Le Fanue - What I Want [NCS R...     130.0      210392
#
#    t_step  datapoint_0  datapoint_1  datapoint_2  datapoint_3  ...  \
# 0  2140.0     0.034883          0.0     0.028439     0.046544  ...
# 1  1520.0     0.044386          0.0     0.043074     0.070807  ...
# 2  1490.0     0.074010          0.0     0.027107     0.052641  ...
# 3  1190.0     0.040056          0.0     0.056302     0.090392  ...
# 4  1300.0     0.021479          0.0     0.028877     0.066285  ...
#
#    datapoint_90  datapoint_91  datapoint_92  datapoint_93  datapoint_94  \
# 0      0.967818      0.964090      0.973908      0.978677      0.989083
# 1      1.000000      0.992251      0.977241      0.977201      0.973159
# 2      0.980443      0.980796      0.983149      0.985826      0.985274
# 3      0.984439      0.991178      0.995789      0.998120      0.999640
# 4      0.996590      0.988758      0.971256      0.962779      0.955974
#
#    datapoint_95  datapoint_96  datapoint_97  datapoint_98  datapoint_99
# 0      1.000000      0.999283      0.998590      0.979921      0.993675
# 1      0.973217      0.973392      0.972385      0.970316      0.975626
# 2      0.975527      0.986906      0.995770      1.000000      0.998612
# 3      0.996690      1.000000      0.990731      0.988720      0.954516
# 4      0.944535      0.933863      0.926431      0.939607      0.922554
#
# [5 rows x 106 columns]

# %%
# try:
#     os.remove('ncs_clean.csv')
# except OSError as e:
#     pass

# ncs_raw.to_csv('ncs_clean.csv', sep=';')

# %%
datapoints = ncs_raw[[f'datapoint_{i}' for i in range(100)]].values
print(datapoints.shape)
t_steps = ncs_raw['t_step'].values
print(t_steps.shape)
# Out:
# (1111, 100)
# (1111,)

# %%
CUTOFF = 0.8
VID_LEN = datapoints.shape[0]
DP_LEN = datapoints.shape[1]

new_start = np.argmax((datapoints[:, 1:] - datapoints[:, :-1]) > 0, axis=1)
datapoints[np.arange(DP_LEN)[np.newaxis, :] < new_start[:, np.newaxis]] = 0
datapoints *= 1 / np.max(datapoints, axis=1)[:, np.newaxis]

peaks = np.argmax(datapoints, axis=1)

start_idxs = np.empty((VID_LEN))
end_idxs = np.empty((VID_LEN))

for i in range(VID_LEN):
    good_dp = datapoints[i] > CUTOFF
    prev_dp = ~good_dp[:peaks[i]][::-1]
    if prev_dp.any():
        start_idxs[i] = peaks[i] - np.argmax(prev_dp)
    else:
        start_idxs[i] = 0

    post_dp = ~good_dp[peaks[i]:]
    if post_dp.any():
        end_idxs[i] = peaks[i] + np.argmax(post_dp)
    else:
        end_idxs[i] = good_dp.shape[0]

start_s = (start_idxs * t_steps) // 1000
end_s = (end_idxs * t_steps) // 1000

print(start_s.shape)
print(end_s.shape)
# Out:
# (1111,)
# (1111,)

# %%
ncs_raw['start_s'] = start_s
ncs_raw['end_s'] = end_s
ncs_raw.head()
# Out:
#                  channel_id     video_id  \
# 0  UC_aEa8K-EOJ3D6gOs7HcyNg  vTLrfrkBDp8
# 1  UC_aEa8K-EOJ3D6gOs7HcyNg  qijbn1Fcq_I
# 2  UC_aEa8K-EOJ3D6gOs7HcyNg  _zvzWG9tKzI
# 3  UC_aEa8K-EOJ3D6gOs7HcyNg  _OLrjAWzUR0
# 4  UC_aEa8K-EOJ3D6gOs7HcyNg  rUt7qOHwh1s
#
#                                                title  duration  view_count  \
# 0               T & Sugah - Indecisive [NCS Release]     214.0      143632
# 1      Raude - paradise (feat. Ntsika) [NCS Release]     152.0      159827
# 2                    C1W - Driver Seat [NCS Release]     149.0      170539
# 3              Clarx & Zaug - No Money [NCS Release]     119.0      228235
# 4  Britt Lari & Ray Le Fanue - What I Want [NCS R...     130.0      210392
#
#    t_step  datapoint_0  datapoint_1  datapoint_2  datapoint_3  ...  \
# 0  2140.0     0.034883          0.0     0.028439     0.046544  ...
# 1  1520.0     0.044386          0.0     0.043074     0.070807  ...
# 2  1490.0     0.074010          0.0     0.027107     0.052641  ...
# 3  1190.0     0.040056          0.0     0.056302     0.090392  ...
# 4  1300.0     0.021479          0.0     0.028877     0.066285  ...
#
#    datapoint_92  datapoint_93  datapoint_94  datapoint_95  datapoint_96  \
# 0      0.973908      0.978677      0.989083      1.000000      0.999283
# 1      0.977241      0.977201      0.973159      0.973217      0.973392
# 2      0.983149      0.985826      0.985274      0.975527      0.986906
# 3      0.995789      0.998120      0.999640      0.996690      1.000000
# 4      0.971256      0.962779      0.955974      0.944535      0.933863
#
#    datapoint_97  datapoint_98  datapoint_99  start_s  end_s
# 0      0.998590      0.979921      0.993675    154.0  214.0
# 1      0.972385      0.970316      0.975626     97.0  152.0
# 2      0.995770      1.000000      0.998612     90.0  149.0
# 3      0.990731      0.988720      0.954516     77.0  119.0
# 4      0.926431      0.939607      0.922554     75.0  130.0
#
# [5 rows x 108 columns]

# %%
print(ncs_raw.shape)
ncs_raw
# Out:
# (1111, 108)
#                     channel_id     video_id  \
# 0     UC_aEa8K-EOJ3D6gOs7HcyNg  vTLrfrkBDp8
# 1     UC_aEa8K-EOJ3D6gOs7HcyNg  qijbn1Fcq_I
# 2     UC_aEa8K-EOJ3D6gOs7HcyNg  _zvzWG9tKzI
# 3     UC_aEa8K-EOJ3D6gOs7HcyNg  _OLrjAWzUR0
# 4     UC_aEa8K-EOJ3D6gOs7HcyNg  rUt7qOHwh1s
# ...                        ...          ...
# 1106  UC_aEa8K-EOJ3D6gOs7HcyNg  CCIfMWt6JSA
# 1107  UC_aEa8K-EOJ3D6gOs7HcyNg  n4tK7LYFxI0
# 1108  UC_aEa8K-EOJ3D6gOs7HcyNg  p7ZsBPK656s
# 1109  UC_aEa8K-EOJ3D6gOs7HcyNg  wmgrnv0-oUc
# 1110  UC_aEa8K-EOJ3D6gOs7HcyNg  0ewGL1NpD84
#
#                                                   title  duration  view_count  \
# 0                  T & Sugah - Indecisive [NCS Release]     214.0      143632
# 1         Raude - paradise (feat. Ntsika) [NCS Release]     152.0      159827
# 2                       C1W - Driver Seat [NCS Release]     149.0      170539
# 3                 Clarx & Zaug - No Money [NCS Release]     119.0      228235
# 4     Britt Lari & Ray Le Fanue - What I Want [NCS R...     130.0      210392
# ...                                                 ...       ...         ...
# 1106                Audioscribe - Skyline [NCS Release]     212.0     1801910
# 1107                     Spektrem - Shine [NCS Release]     259.0   156207083
# 1108                    Disfigure - Blank [NCS Release]     209.0   239122722
# 1109  Tetrix Bass Feat. Veela - The Light [NCS Release]     186.0     9227280
# 1110             SirensCeol - Coming Home [NCS Release]     283.0    13113569
#
#       t_step  datapoint_0  datapoint_1  datapoint_2  datapoint_3  ...  \
# 0     2140.0     0.034883     0.000000     0.028439     0.046544  ...
# 1     1520.0     0.044386     0.000000     0.043074     0.070807  ...
# 2     1490.0     0.074010     0.000000     0.027107     0.052641  ...
# 3     1190.0     0.040056     0.000000     0.056302     0.090392  ...
# 4     1300.0     0.021479     0.000000     0.028877     0.066285  ...
# ...      ...          ...          ...          ...          ...  ...
# 1106  2130.0     0.453432     0.000000     0.115729     0.258168  ...
# 1107  2600.0     0.662456     0.596953     0.689271     0.739346  ...
# 1108  2100.0     0.575763     0.384747     0.491645     0.539842  ...
# 1109  1870.0     0.716945     0.726637     0.926572     0.966144  ...
# 1110  2840.0     0.000000     0.074492     0.191215     0.252043  ...
#
#       datapoint_92  datapoint_93  datapoint_94  datapoint_95  datapoint_96  \
# 0         0.973908      0.978677      0.989083      1.000000      0.999283
# 1         0.977241      0.977201      0.973159      0.973217      0.973392
# 2         0.983149      0.985826      0.985274      0.975527      0.986906
# 3         0.995789      0.998120      0.999640      0.996690      1.000000
# 4         0.971256      0.962779      0.955974      0.944535      0.933863
# ...            ...           ...           ...           ...           ...
# 1106      0.594337      0.580100      0.568938      0.558804      0.546753
# 1107      0.123915      0.096266      0.073607      0.053435      0.034276
# 1108      0.074490      0.058300      0.049721      0.034691      0.022170
# 1109      0.335049      0.319443      0.304942      0.283763      0.250359
# 1110      0.337672      0.315058      0.283421      0.233786      0.165433
#
#       datapoint_97  datapoint_98  datapoint_99  start_s  end_s
# 0         0.998590      0.979921      0.993675    154.0  214.0
# 1         0.972385      0.970316      0.975626     97.0  152.0
# 2         0.995770      1.000000      0.998612     90.0  149.0
# 3         0.990731      0.988720      0.954516     77.0  119.0
# 4         0.926431      0.939607      0.922554     75.0  130.0
# ...            ...           ...           ...      ...    ...
# 1106      0.528712      0.508046      0.480102     97.0  106.0
# 1107      0.017020      0.004131      0.000000     15.0   59.0
# 1108      0.011524      0.000490      0.000000     21.0   44.0
# 1109      0.169170      0.064012      0.000000      3.0   28.0
# 1110      0.109037      0.131751      0.022084     62.0   82.0
#
# [1111 rows x 108 columns]

# %%
MAX_SONG_LEN = 240
ncs_raw.loc[ncs_raw['end_s'] > ncs_raw['duration'], 'end_s'] = ncs_raw[ncs_raw['end_s'] > ncs_raw['duration']]['duration']
ncs_raw = ncs_raw[ncs_raw['start_s'] < MAX_SONG_LEN]
ncs_raw.loc[ncs_raw['end_s'] > MAX_SONG_LEN, 'end_s'] = MAX_SONG_LEN
ncs_raw.shape
# Out:
# (1110, 108)

# %%
print(ncs_raw.shape)
ncs_raw.head()
# Out:
# (1110, 108)
#                  channel_id     video_id  \
# 0  UC_aEa8K-EOJ3D6gOs7HcyNg  vTLrfrkBDp8
# 1  UC_aEa8K-EOJ3D6gOs7HcyNg  qijbn1Fcq_I
# 2  UC_aEa8K-EOJ3D6gOs7HcyNg  _zvzWG9tKzI
# 3  UC_aEa8K-EOJ3D6gOs7HcyNg  _OLrjAWzUR0
# 4  UC_aEa8K-EOJ3D6gOs7HcyNg  rUt7qOHwh1s
#
#                                                title  duration  view_count  \
# 0               T & Sugah - Indecisive [NCS Release]     214.0      143632
# 1      Raude - paradise (feat. Ntsika) [NCS Release]     152.0      159827
# 2                    C1W - Driver Seat [NCS Release]     149.0      170539
# 3              Clarx & Zaug - No Money [NCS Release]     119.0      228235
# 4  Britt Lari & Ray Le Fanue - What I Want [NCS R...     130.0      210392
#
#    t_step  datapoint_0  datapoint_1  datapoint_2  datapoint_3  ...  \
# 0  2140.0     0.034883          0.0     0.028439     0.046544  ...
# 1  1520.0     0.044386          0.0     0.043074     0.070807  ...
# 2  1490.0     0.074010          0.0     0.027107     0.052641  ...
# 3  1190.0     0.040056          0.0     0.056302     0.090392  ...
# 4  1300.0     0.021479          0.0     0.028877     0.066285  ...
#
#    datapoint_92  datapoint_93  datapoint_94  datapoint_95  datapoint_96  \
# 0      0.973908      0.978677      0.989083      1.000000      0.999283
# 1      0.977241      0.977201      0.973159      0.973217      0.973392
# 2      0.983149      0.985826      0.985274      0.975527      0.986906
# 3      0.995789      0.998120      0.999640      0.996690      1.000000
# 4      0.971256      0.962779      0.955974      0.944535      0.933863
#
#    datapoint_97  datapoint_98  datapoint_99  start_s  end_s
# 0      0.998590      0.979921      0.993675    154.0  214.0
# 1      0.972385      0.970316      0.975626     97.0  152.0
# 2      0.995770      1.000000      0.998612     90.0  149.0
# 3      0.990731      0.988720      0.954516     77.0  119.0
# 4      0.926431      0.939607      0.922554     75.0  130.0
#
# [5 rows x 108 columns]

# %%
ncs_raw.reset_index(drop=True, inplace=True)
print(ncs_raw.shape)
print(list(ncs_raw.index)[-10:])
# Out:
# (1110, 108)
# [1100, 1101, 1102, 1103, 1104, 1105, 1106, 1107, 1108, 1109]

# %%
ncs_raw.to_csv('ncs.csv', sep=';')
